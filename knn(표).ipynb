# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
import seaborn as sns
plt.rcParams['axes.unicode_minus']=False
plt.rcParams['figure.figsize']=(12,9)
df_표 = pd.read_csv('data/어장환경관측자료(표층).csv')
df_저 = pd.read_csv('data/어장환경관측자료(저층).csv')

# %%
font_path = "data/서울한강 장체EB.TTF"  # 실제 한글 폰트 파일 경로로 변경해야 합니다.
font_name = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font_name)

# %%
df_표.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15119 entries, 0 to 15118
# Data columns (total 28 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   어장명         15119 non-null  object
#  1   정점          15119 non-null  int64
#  2   정점2         15119 non-null  int64
#  3   위도          15119 non-null  float64
#  4   경도          15119 non-null  float64
#  5   어장종류        15118 non-null  object
#  6   년도          15119 non-null  int64
#  7   월           15119 non-null  int64
#  8   일           15119 non-null  int64
#  9   기상          15119 non-null  object
#  10  수심(m)       15111 non-null  float64
#  11  수온(표)       15119 non-null  float64
#  12  수온(차이)      15119 non-null  float64
#  13  염분(표)       15119 non-null  float64
#  14  Ph(표)       15119 non-null  float64
#  15  DO(표)       15119 non-null  float64
#  16  COD(표)      15119 non-null  float64
#  17  NH4-N(표)    15119 non-null  float64
# ...

# %%
df_표.isnull().sum()
# Out:
# 어장명             0
# 정점              0
# 정점2             0
# 위도              0
# 경도              0
# 어장종류            1
# 년도              0
# 월               0
# 일               0
# 기상              0
# 수심(m)           8
# 수온(표)           0
# 수온(차이)          0
# 염분(표)           0
# Ph(표)           0
# DO(표)           0
# COD(표)          0
# NH4-N(표)        0
# NO3-N(표)        0
# NO2-N(표)        0
# DIN(표)          0
# TN(표)           0
# DIP(표)          0
# TP(표)           0
# SIO2-SI(표)      0
# CHL-A(표)        0
# SS(표)           0
# 투명도           221
# dtype: int64

# %%
# df_표 = df_표.dropna()

# %%
# df_표.isnull().sum()

# %%
(df_표['DO(표)']<=3).value_counts()
# df_표 = df[(df['DO(표)']<=3)]
# df_표
# csv_filename = 'filtered_data(표).csv'
# df_표.to_csv(csv_filename, index=False)

# print(f"Filtered data saved to {csv_filename}")
# Out:
# False    15114
# True         5
# Name: DO(표), dtype: int64

# %%
df1 = df_표[df_표['DO(표)']<=3] #표층 DO가 3이하인 데이터 5개
df1
# Out:
#        어장명  정점  정점2         위도          경도 어장종류    년도   월   일 기상  ...  \
# 70    가로림만   6    8  36.931111  126.344722   패류  2010  12   1  -  ...
# 76    가로림만   4    7  36.914444  126.365278   패류  2010  12   1  -  ...
# 8367    완도   1    2  34.584167  127.719722  해조류  2009   5  12  -  ...
# 8373    완도   3    3  34.573611  127.687222  해조류  2009   5  13  -  ...
# 8378    완도   2    1  34.572500  127.729444  해조류  2009   5  13  -  ...
#
#       NO3-N(표)  NO2-N(표)  DIN(표)  TN(표)  DIP(표)  TP(표)  SIO2-SI(표)  CHL-A(표)  \
# 70       0.121     0.004   0.134  0.892   0.023  0.029       0.306      0.15
# 76       0.127     0.005   0.139  0.963   0.023  0.025       0.289      0.18
# 8367     0.020     0.019   0.132  0.892   0.004  0.024       0.289      1.75
# 8373     0.034     0.019   0.148  0.963   0.012  0.028       0.255      1.90
# 8378     0.027     0.018   0.142  1.007   0.006  0.026       0.211      2.50
#
#       SS(표)  투명도
# 70     35.0  0.8
# 76     31.6  0.7
# 8367  137.0  1.2
# ...

# %%
df1_ = df_표[df_표['DO(표)']>3]#표층 DO가 3초과 데이터 15074개

# %%
df1_ = df1_[df1_['DO(표)']<60]

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df1['DIN(표)'], df1['DO(표)'], color='blue', label='빈산소수괴 발생')
plt.scatter(df1_['DIN(표)'], df1_['DO(표)'], color='orange', label='정상 데이터')
plt.xlabel('DIN(표)')
plt.ylabel('DO(표)')
plt.title('빈산소수괴 VS 정상 데이터 산점도')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df1['Ph(표)'], df1['DO(표)'], color='blue', label='빈산소수괴 발생')
plt.scatter(df1_['Ph(표)'], df1_['DO(표)'], color='orange', label='정상 데이터')
plt.xlabel('Ph((표)')
plt.ylabel('DO(표)')
plt.title('빈산소수괴 VS 정상 데이터 산점도')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df1['TN(표)'], df1['DO(표)'], color='blue', label='빈산소수괴 발생')
plt.scatter(df1_['TN(표)'], df1_['DO(표)'], color='orange', label='정상 데이터')
plt.xlabel('TN(표)')
plt.ylabel('DO(표)')
plt.title('빈산소수괴 VS 정상 데이터 산점도')
plt.legend()
plt.grid(True)
plt.show()

# %%
df1_가막만 = df1_[df1_['어장명']=='가막만'] #표층 3이상 가막만 데이터
df1_가막만
# Out:
#      어장명  정점  정점2         위도          경도 어장종류    년도  월   일 기상  ...  NO3-N(표)  \
# 134  가막만   8   38  34.759722  127.552500   어류  2009  9  16  -  ...     0.070
# 135  가막만   8   38  34.759722  127.552500   어류  2009  8   6  -  ...     0.026
# 136  가막만   8   38  34.759722  127.552500   어류  2009  7   2  -  ...     0.019
# 137  가막만   8   38  34.759722  127.552500   어류  2009  5  14  -  ...     0.025
# 138  가막만   9   37  34.744722  127.413889   어류  2009  9   9  -  ...     0.030
# ..   ...  ..  ...        ...         ...  ...   ... ..  .. ..  ...       ...
# 811  가막만   4    1  34.232222  126.553611   패류  2009  9   8  -  ...     0.034
# 812  가막만   4    1  34.232222  126.553611   패류  2009  8   5  -  ...     0.051
# 813  가막만   4    1  34.232222  126.553611   패류  2009  7   8  -  ...     0.012
# 814  가막만   4    1  34.232222  126.553611   패류  2009  5  12  -  ...     0.019
# 815  가막만   4    1  34.232222  126.553611   패류  2009  2  19  -  ...     0.038
#
# ...

# %%
df1_가막만 = df1_가막만[(df1_가막만['정점'] == 10) & (df1_가막만['어장명'] == '가막만')]
# df1_가막만

# %%
# 산점도 시각화
plt.figure(figsize=(10, 6))
plt.scatter(df1가막만['SIO2-SI(표)'], df1가막만['DO(표)'], color='blue', label='빈산소수괴 발생')
plt.scatter(df1_가막만['SIO2-SI(표)'], df1_가막만['DO(표)'], color='orange', label='정상 데이터')
plt.xlabel('SIO2-SI(표)')
plt.ylabel('DO(표)')
plt.title('빈산소수괴 VS 정상 데이터 산점도')
plt.legend()
plt.grid(True)
plt.show()

# %%
# 산점도 시각화
plt.figure(figsize=(10, 6))
plt.scatter(df1가막만['TN(표)'], df1가막만['DO(표)'], color='blue', label='빈산소수괴 발생')
plt.scatter(df1_가막만['TN(표)'], df1_가막만['DO(표)'], color='orange', label='정상 데이터')
plt.xlabel('TN(표)')
plt.ylabel('DO(표)')
plt.title('빈산소수괴 VS 정상 데이터 산점도')
plt.legend()
plt.grid(True)
plt.show()

# %%
# 산점도 시각화
plt.figure(figsize=(10, 6))
plt.scatter(df1가막만['SIO2-SI(표)'], df1가막만['DO(표)'], color='blue', label='빈산소수괴 발생')
plt.scatter(df1_가막만['SIO2-SI(표)'], df1_가막만['DO(표)'], color='orange', label='정상 데이터')
plt.xlabel('SIO2-SI(표)')
plt.ylabel('DO(표)')
plt.title('빈산소수괴 VS 정상 데이터 산점도')
plt.legend()
plt.grid(True)

# %%
# 산점도 시각화
plt.figure(figsize=(10, 6))
plt.scatter(df1가막만['수온(차이)'], df1가막만['DO(표)'], color='blue', label='빈산소수괴 발생')
plt.scatter(df1_가막만['수온(차이)'], df1_가막만['DO(표)'], color='orange', label='정상 데이터')
plt.xlabel('수온 차이')
plt.ylabel('DO(표)')
plt.title('빈산소수괴 VS 정상 데이터 산점도')
plt.legend()
plt.grid(True)
plt.show()

# %%
df완도 = df1[df1['어장명']=='완도'] #표층 3이하 가막만 데이터
df완도
# Out:
#      어장명  정점  정점2         위도          경도 어장종류    년도  월   일 기상  ...  NO3-N(표)  \
# 8367  완도   1    2  34.584167  127.719722  해조류  2009  5  12  -  ...     0.020
# 8373  완도   3    3  34.573611  127.687222  해조류  2009  5  13  -  ...     0.034
# 8378  완도   2    1  34.572500  127.729444  해조류  2009  5  13  -  ...     0.027
#
#       NO2-N(표)  DIN(표)  TN(표)  DIP(표)  TP(표)  SIO2-SI(표)  CHL-A(표)  SS(표)  투명도
# 8367     0.019   0.132  0.892   0.004  0.024       0.289      1.75  137.0  1.2
# 8373     0.019   0.148  0.963   0.012  0.028       0.255      1.90   24.0  1.5
# 8378     0.018   0.142  1.007   0.006  0.026       0.211      2.50  102.0  1.3
#
# [3 rows x 28 columns]

# %%
df1완도 = df1[df1['어장명']=='완도'] #표층 3이하 가막만 데이터
df1완도
# Out:
#      어장명  정점  정점2         위도          경도 어장종류    년도  월   일 기상  ...  NO3-N(표)  \
# 8367  완도   1    2  34.584167  127.719722  해조류  2009  5  12  -  ...     0.020
# 8373  완도   3    3  34.573611  127.687222  해조류  2009  5  13  -  ...     0.034
# 8378  완도   2    1  34.572500  127.729444  해조류  2009  5  13  -  ...     0.027
#
#       NO2-N(표)  DIN(표)  TN(표)  DIP(표)  TP(표)  SIO2-SI(표)  CHL-A(표)  SS(표)  투명도
# 8367     0.019   0.132  0.892   0.004  0.024       0.289      1.75  137.0  1.2
# 8373     0.019   0.148  0.963   0.012  0.028       0.255      1.90   24.0  1.5
# 8378     0.018   0.142  1.007   0.006  0.026       0.211      2.50  102.0  1.3
#
# [3 rows x 28 columns]

# %%
df1완도 = df1완도[(df1완도['정점'] == 1) & (df1완도['어장명'] == '완도')]
df1완도
# Out:
#      어장명  정점  정점2         위도          경도 어장종류    년도  월   일 기상  ...  NO3-N(표)  \
# 8367  완도   1    2  34.584167  127.719722  해조류  2009  5  12  -  ...      0.02
#
#       NO2-N(표)  DIN(표)  TN(표)  DIP(표)  TP(표)  SIO2-SI(표)  CHL-A(표)  SS(표)  투명도
# 8367     0.019   0.132  0.892   0.004  0.024       0.289      1.75  137.0  1.2
#
# [1 rows x 28 columns]

# %%
df1_완도 = df1_[(df1_['정점'] == 1) & (df1_['어장명'] == '완도')]
df1_완도
df1_완도.head()
# Out:
#      어장명  정점  정점2         위도          경도 어장종류    년도  월   일  기상  ...  NO3-N(표)  \
# 8364  완도   1    2  34.584167  127.719722  해조류  2009  9   8   -  ...     0.029
# 8365  완도   1    2  34.584167  127.719722  해조류  2009  8   5   -  ...     0.054
# 8366  완도   1    2  34.584167  127.719722  해조류  2009  7   8   -  ...     0.026
# 8368  완도   1    2  34.584167  127.719722  해조류  2009  2  18   -  ...     0.024
# 8421  완도   1    5  34.417500  127.079167   어류  2022  2   8  맑음  ...     0.002
#
#       NO2-N(표)    DIN(표)     TN(표)  DIP(표)  TP(표)  SIO2-SI(표)  CHL-A(표)  \
# 8364     0.004  0.048605  0.590592   0.004  0.030       0.214      2.35
# 8365     0.007  0.041348  0.629380   0.003  0.029       0.386      5.08
# 8366     0.029  0.058212  0.688670   0.005  0.017       0.201      4.18
# 8368     0.119  0.044466  0.629963   0.017  0.024       0.349      0.80
# 8421     0.076  0.058580  0.544213   0.014  0.030       0.331      0.65
#
#       SS(표)  투명도
# 8364   19.2  1.1
# 8365   16.8  2.0
# ...

# %%
# 산점도 시각화
plt.figure(figsize=(10, 6))
plt.scatter(df1완도['SIO2-SI(표)'], df1완도['DO(표)'], color='blue', label='빈산소수괴 발생')
plt.scatter(df1_완도['SIO2-SI(표)'], df1_완도['DO(표)'], color='orange', label='정상 데이터')
plt.xlabel('SIO2-SI(표)')
plt.ylabel('DO(표)')
plt.title('빈산소수괴 VS 정상 데이터 산점도')
plt.legend()
plt.grid(True)
plt.show()

# %%
# 산점도 시각화
plt.figure(figsize=(10, 6))
plt.scatter(df1완도['TN(표)'], df1완도['DO(표)'], color='blue', label='빈산소수괴 발생')
plt.scatter(df1_완도['TN(표)'], df1_완도['DO(표)'], color='orange', label='정상 데이터')
plt.xlabel('TN(표)')
plt.ylabel('DO(표)')
plt.title('빈산소수괴 VS 정상 데이터 산점도')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# 결론 :: 표층에는 어떤 독립변수가 빈산소수괴에 영향을 미치는지 알 수 없다.

# %%
for i in range(df1.shape[0]):
  print(df1.iloc[i]['위도'], df1.iloc[i]['경도'] )
# Out:
# 36.9311111111111 126.344722222222
# 36.9144444444444 126.365277777778
# 34.5841666666667 127.719722222222
# 34.5736111111111 127.687222222222
# 34.5725 127.729444444444

# %%
# import folium
# m = folium.Map(
#     location=[35.0211,128.6810],
#     zoom_start=10
# )

# tooltip = 'Click'

# # for문, f-string이용
# for i in range(df1.shape[0]):
#     folium.Marker(
#         [df1.iloc[i]['위도'], df1.iloc[i]['경도']],
#         popup = f'<strong>{df1.iloc[i]["어장명"]}</br>{df1.iloc[i]["정점2"]}</strong>',
#         tooltip = tooltip
#     ).add_to(m)
# m

# %%
# import pandas as pd

# # 행별로 0인 값의 개수를 세어 새로운 컬럼을 만듭니다.
# df_표['zero_count'] = (df_표 == 0).sum(axis=1)

# # 0인 값의 개수가 2개 이상인 행들을 선택합니다.
# rows_to_delete = df_표[df_표['zero_count'] >= 2]

# # 선택된 행들을 삭제합니다.
# df_표 = df_표.drop(rows_to_delete.index)

# # 'zero_count' 컬럼을 삭제합니다.
# df_표= df_표.drop('zero_count', axis=1)

# # 결과 데이터프레임을 확인합니다.
# print(df_저)

# %%
# import folium
# m = folium.Map(
#     location=[35.0211,128.6810],
#     zoom_start=10
# )

# tooltip = 'Click'

# # for문, f-string이용
# for i in range(df_표.shape[0]):
#     folium.Marker(
#         [df_표.iloc[i]['위도'], df_표.iloc[i]['경도']],
#         popup = f'<strong>{df_표.iloc[i]["어장명"]}</br>{df_표.iloc[i]["정점"]}</strong>',
#         tooltip = tooltip
#     ).add_to(m)
# m

# %%
df가로림만 = df_표[df_표['어장명']=='가로림만'] 
df가로림만
# Out:
#       어장명  정점  정점2         위도          경도 어장종류    년도   월   일  기상  ...  \
# 0    가로림만   1   15  36.993056  126.311111    김  2021  12  11  맑음  ...
# 1    가로림만   1   15  36.993056  126.311111    김  2021  10  13  맑음  ...
# 2    가로림만   1   15  36.993056  126.311111    김  2021   8   2  흐림  ...
# 3    가로림만   1   15  36.993056  126.311111    김  2021   6   9  맑음  ...
# 4    가로림만   1   15  36.993056  126.311111    김  2021   4   1  맑음  ...
# ..    ...  ..  ...        ...         ...  ...   ...  ..  ..  ..  ...
# 129  가로림만   4    1  36.855000  126.310000  바지락  2019   6  12  맑음  ...
# 130  가로림만   4    1  36.855000  126.310000  바지락  2019   4   8  맑음  ...
# 131  가로림만   4    1  36.855000  126.310000  바지락  2019   2  14  맑음  ...
# 132  가로림만   4    1  36.855000  126.310000  바지락  2016   4   7  맑음  ...
# 133  가로림만   4    1  36.855000  126.310000  바지락  2016   2  21  맑음  ...
#
#      NO3-N(표)  NO2-N(표)    DIN(표)     TN(표)  DIP(표)  TP(표)  SIO2-SI(표)  \
# ...

# %%
df완도 = df_표[df_표['어장명']=='완도'] 
df완도
# Out:
#      어장명  정점  정점2         위도          경도 어장종류    년도  월   일 기상  ...  NO3-N(표)  \
# 8359  완도   4    4  34.599722  127.663889  해조류  2009  9   8  -  ...     0.034
# 8360  완도   4    4  34.599722  127.663889  해조류  2009  8   5  -  ...     0.053
# 8361  완도   4    4  34.599722  127.663889  해조류  2009  7   8  -  ...     0.025
# 8362  완도   4    4  34.599722  127.663889  해조류  2009  5  12  -  ...     0.011
# 8363  완도   4    4  34.599722  127.663889  해조류  2009  2  12  -  ...     0.019
# ...   ..  ..  ...        ...         ...  ...   ... ..  .. ..  ...       ...
# 9146  완도  14   36  33.465556  126.310833   패류  2009  9  17  -  ...     0.094
# 9147  완도  14   36  33.465556  126.310833   패류  2009  8  13  -  ...     0.050
# 9148  완도  14   36  33.465556  126.310833   패류  2009  7  23  -  ...     0.010
# 9149  완도  14   36  33.465556  126.310833   패류  2009  5  19  -  ...     0.013
# 9150  완도  14   36  33.465556  126.310833   패류  2009  2   9  -  ...     0.033
#
# ...

# %%
df가로림만무 = df가로림만[df가로림만['DO(표)']>3] #표층 DO가 3초과 데이터 4개
df가로림만무
# Out:
#       어장명  정점  정점2         위도          경도 어장종류    년도   월   일  기상  ...  \
# 0    가로림만   1   15  36.993056  126.311111    김  2021  12  11  맑음  ...
# 1    가로림만   1   15  36.993056  126.311111    김  2021  10  13  맑음  ...
# 2    가로림만   1   15  36.993056  126.311111    김  2021   8   2  흐림  ...
# 3    가로림만   1   15  36.993056  126.311111    김  2021   6   9  맑음  ...
# 4    가로림만   1   15  36.993056  126.311111    김  2021   4   1  맑음  ...
# ..    ...  ..  ...        ...         ...  ...   ...  ..  ..  ..  ...
# 129  가로림만   4    1  36.855000  126.310000  바지락  2019   6  12  맑음  ...
# 130  가로림만   4    1  36.855000  126.310000  바지락  2019   4   8  맑음  ...
# 131  가로림만   4    1  36.855000  126.310000  바지락  2019   2  14  맑음  ...
# 132  가로림만   4    1  36.855000  126.310000  바지락  2016   4   7  맑음  ...
# 133  가로림만   4    1  36.855000  126.310000  바지락  2016   2  21  맑음  ...
#
#      NO3-N(표)  NO2-N(표)    DIN(표)     TN(표)  DIP(표)  TP(표)  SIO2-SI(표)  \
# ...

# %%
df가로림만유 = df가로림만[df가로림만['DO(표)']<=3] #표층 DO가 3초과 데이터 4개
df가로림만유
# Out:
#      어장명  정점  정점2         위도          경도 어장종류    년도   월  일 기상  ...  NO3-N(표)  \
# 70  가로림만   6    8  36.931111  126.344722   패류  2010  12  1  -  ...     0.121
# 76  가로림만   4    7  36.914444  126.365278   패류  2010  12  1  -  ...     0.127
#
#     NO2-N(표)  DIN(표)  TN(표)  DIP(표)  TP(표)  SIO2-SI(표)  CHL-A(표)  SS(표)  투명도
# 70     0.004   0.134  0.892   0.023  0.029       0.306      0.15   35.0  0.8
# 76     0.005   0.139  0.963   0.023  0.025       0.289      0.18   31.6  0.7
#
# [2 rows x 28 columns]

# %%
df가로림만 = df가로림만[(df가로림만['정점2'] == 8)]

# %%
df완도 = df완도[(df완도['정점2'] == 3)]

# %%
df가로림만
# Out:
#      어장명  정점  정점2         위도          경도 어장종류    년도   월  일 기상  ...  NO3-N(표)  \
# 70  가로림만   6    8  36.931111  126.344722   패류  2010  12  1  -  ...     0.121
# 71  가로림만   6    8  36.931111  126.344722   패류  2010  10  6  -  ...     0.036
# 72  가로림만   6    8  36.931111  126.344722   패류  2010   8  8  -  ...     0.026
# 73  가로림만   6    8  36.931111  126.344722   패류  2010   6  8  -  ...     0.112
# 74  가로림만   6    8  36.931111  126.344722   패류  2010   4  3  -  ...     0.093
# 75  가로림만   6    8  36.931111  126.344722   패류  2010   2  4  -  ...     0.142
#
#     NO2-N(표)    DIN(표)     TN(표)  DIP(표)  TP(표)  SIO2-SI(표)  CHL-A(표)  SS(표)  \
# 70     0.004  0.134000  0.892000   0.023  0.029       0.306      0.15   35.0
# 71     0.028  0.021742  0.441014   0.013  0.018       0.150      0.19   29.2
# 72     0.005  0.021757  0.401297   0.009  0.020       0.150      1.62    8.6
# 73     0.004  0.021765  0.453442   0.012  0.031       0.271      0.72   23.6
# ...

# %%
df가로림만 = df가로림만[['수온(표)','수온(차이)','염분(표)','Ph(표)',
           'COD(표)', 'NH4-N(표)', 'NO3-N(표)', 'NO2-N(표)','DO(표)',
           'DIN(표)', 'TN(표)', 'DIP(표)', 'TP(표)','SIO2-SI(표)','CHL-A(표)','SS(표)','투명도']]

# %%
df완도 = df완도[['수온(표)','수온(차이)','염분(표)','Ph(표)',
           'COD(표)', 'NH4-N(표)', 'NO3-N(표)', 'NO2-N(표)','DO(표)',
           'DIN(표)', 'TN(표)', 'DIP(표)', 'TP(표)','SIO2-SI(표)','CHL-A(표)','SS(표)','투명도']]

# %%
가로림만_corr = df가로림만.corr()

# %%
완도_corr = df완도.corr()

# %%
tips_corr_heatmap = sns.heatmap(가로림만_corr,
                                cbar=True,
                                annot=True,
                                cmap='GnBu',
                                vmin=-1.0,
                                vmax=1.0)
plt.figure(figsize=(12, 9))
plt.show()

# %%
tips_corr_heatmap = sns.heatmap(완도_corr,
                                cbar=True,
                                annot=True,
                                cmap='GnBu',
                                vmin=-1.0,
                                vmax=1.0)
plt.figure(figsize=(12, 9))
plt.show()

# %% [markdown]
# 전체 데이터 히트맵

# %%
df_표 = df_표[['수온(표)','수온(차이)','염분(표)','Ph(표)',
           'COD(표)', 'NH4-N(표)', 'NO3-N(표)', 'NO2-N(표)','DO(표)',
           'DIN(표)', 'TN(표)', 'DIP(표)', 'TP(표)','SIO2-SI(표)','CHL-A(표)','SS(표)','투명도']]

# %%
df1 = df1[['수온(표)','수온(차이)','염분(표)','Ph(표)',
           'COD(표)', 'NH4-N(표)', 'NO3-N(표)', 'NO2-N(표)','DO(표)',
           'DIN(표)', 'TN(표)', 'DIP(표)', 'TP(표)','SIO2-SI(표)','CHL-A(표)','SS(표)','투명도']]

# %%
df1_ = df1_[['수온(표)','수온(차이)','염분(표)','Ph(표)',
           'COD(표)', 'NH4-N(표)', 'NO3-N(표)', 'NO2-N(표)','DO(표)',
           'DIN(표)', 'TN(표)', 'DIP(표)', 'TP(표)','SIO2-SI(표)','CHL-A(표)','SS(표)','투명도']]

# %%
표_corr = df_표.corr()

# %%
df1_corr = df1.corr()

# %%
df1__corr = df1_.corr()

# %%
# 표층 DO와 표층 DIN 간의 상관관계 분석
tips_corr_heatmap = sns.heatmap(표_corr,
                                cbar=True,
                                annot=True,
                                cmap='GnBu',
                                vmin=-1.0,
                                vmax=1.0)
plt.figure(figsize=(12, 9))
plt.show()

# %%
tips_corr_heatmap = sns.heatmap(df1_corr,
                                cbar=True,
                                annot=True,
                                cmap='GnBu',
                                vmin=-1.0,
                                vmax=1.0)
plt.figure(figsize=(12, 9))
plt.show()

# %%
tips_corr_heatmap = sns.heatmap(df1__corr,
                                cbar=True,
                                annot=True,
                                cmap='GnBu',
                                vmin=-1.0,
                                vmax=1.0)
plt.figure(figsize=(12, 9))
plt.show()

# %%
표_corr = df_표.corr()
