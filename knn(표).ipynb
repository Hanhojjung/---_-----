# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
import seaborn as sns
plt.rcParams['axes.unicode_minus']=False
plt.rcParams['figure.figsize']=(12,9)
df_표 = pd.read_csv('data/어장환경관측자료(표층).csv')
df_저 = pd.read_csv('data/어장환경관측자료(저층).csv')

# %%
font_path = "data/서울한강 장체EB.TTF"  # 실제 한글 폰트 파일 경로로 변경해야 합니다.
font_name = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font_name)

# %%
df_표.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15121 entries, 0 to 15120
# Data columns (total 28 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   어장명         15121 non-null  object
#  1   정점          15121 non-null  int64
#  2   정점2         15121 non-null  int64
#  3   위도          15121 non-null  float64
#  4   경도          15121 non-null  float64
#  5   어장종류        15120 non-null  object
#  6   년도          15121 non-null  int64
#  7   월           15121 non-null  int64
#  8   일           15121 non-null  int64
#  9   기상          15121 non-null  object
#  10  수심(m)       15113 non-null  float64
#  11  수온(표)       15121 non-null  float64
#  12  수온(차이)      15121 non-null  float64
#  13  염분(표)       15121 non-null  float64
#  14  Ph(표)       15121 non-null  float64
#  15  DO(표)       15121 non-null  float64
#  16  COD(표)      15121 non-null  float64
#  17  NH4-N(표)    15121 non-null  float64
#  18  NO3-N(표)    15121 non-null  float64
#  19  NO2-N(표)    15121 non-null  float64
#  20  DIN(표)      15121 non-null  float64
#  21  TN(표)       15121 non-null  float64
#  22  DIP(표)      15121 non-null  float64
#  23  TP(표)       15121 non-null  float64
#  24  SIO2-SI(표)  15121 non-null  float64
#  25  CHL-A(표)    15121 non-null  float64
#  26  SS(표)       15121 non-null  float64
#  27  투명도         14900 non-null  float64
# dtypes: float64(20), int64(5), object(3)
# memory usage: 3.2+ MB

# %%
df_표.isnull().sum()
# Out:
# 어장명             0
# 정점              0
# 정점2             0
# 위도              0
# 경도              0
# 어장종류            1
# 년도              0
# 월               0
# 일               0
# 기상              0
# 수심(m)           8
# 수온(표)           0
# 수온(차이)          0
# 염분(표)           0
# Ph(표)           0
# DO(표)           0
# COD(표)          0
# NH4-N(표)        0
# NO3-N(표)        0
# NO2-N(표)        0
# DIN(표)          0
# TN(표)           0
# DIP(표)          0
# TP(표)           0
# SIO2-SI(표)      0
# CHL-A(표)        0
# SS(표)           0
# 투명도           221
# dtype: int64

# %%
df_표 = df_표.dropna()

# %%
df_표.isnull().sum()
# Out:
# 어장명           0
# 정점            0
# 정점2           0
# 위도            0
# 경도            0
# 어장종류          0
# 년도            0
# 월             0
# 일             0
# 기상            0
# 수심(m)         0
# 수온(표)         0
# 수온(차이)        0
# 염분(표)         0
# Ph(표)         0
# DO(표)         0
# COD(표)        0
# NH4-N(표)      0
# NO3-N(표)      0
# NO2-N(표)      0
# DIN(표)        0
# TN(표)         0
# DIP(표)        0
# TP(표)         0
# SIO2-SI(표)    0
# CHL-A(표)      0
# SS(표)         0
# 투명도           0
# dtype: int64

# %%
(df_표['DO(표)']<=3).value_counts()
# df_표 = df[(df['DO(표)']<=3)]
# df_표
# csv_filename = 'filtered_data(표).csv'
# df_표.to_csv(csv_filename, index=False)

# print(f"Filtered data saved to {csv_filename}")
# Out:
# False    14894
# True         5
# Name: DO(표), dtype: int64

# %%
df1 = df_표[df_표['DO(표)']<=3] #표층 DO가 3이하인 데이터 4개
df1
# Out:
#         어장명  정점  정점2         위도          경도 어장종류    년도   월   일 기상  ...  \
# 1994   가로림만   6    8  36.931111  126.344722   패류  2010  12   1  -  ...
# 2000   가로림만   4    7  36.914444  126.365278   패류  2010  12   1  -  ...
# 12255    완도   1    2  34.584167  127.719722  해조류  2009   5  12  -  ...
# 12384    완도   3    3  34.573611  127.687222  해조류  2009   5  13  -  ...
# 12437    완도   2    1  34.572500  127.729444  해조류  2009   5  13  -  ...
#
#        NO3-N(표)  NO2-N(표)  DIN(표)  TN(표)  DIP(표)  TP(표)  SIO2-SI(표)  CHL-A(표)  \
# 1994      0.121     0.004   0.134  0.512   0.023  0.029       0.306      0.15
# 2000      0.127     0.005   0.139  0.409   0.023  0.025       0.289      0.18
# 12255     0.020     0.019   0.040  0.892   0.004  0.024       0.289      1.75
# 12384     0.034     0.019   0.053  0.963   0.012  0.028       0.255      1.90
# 12437     0.027     0.018   0.047  1.007   0.006  0.026       0.211      2.50
#
#        SS(표)  투명도
# 1994    35.0  0.8
# 2000    31.6  0.7
# 12255  137.0  1.2
# 12384   24.0  1.5
# 12437  102.0  1.3
#
# [5 rows x 28 columns]

# %%
df1_ = df_표[df_표['DO(표)']>3] #표층 DO가 3초과 데이터 4개
df1_
# Out:
#        어장명  정점  정점2          위도          경도 어장종류    년도   월   일 기상  ...  \
# 0      곰소만   2   38  126.589167   35.565833   패류  2011  12   1  -  ...
# 1      곰소만   2   38  126.589167   35.565833   패류  2011  10   1  -  ...
# 2      곰소만   2   38  126.589167   35.565833   패류  2011   8   1  -  ...
# 3      곰소만   2   38  126.589167   35.565833   패류  2011   6   1  -  ...
# 4      곰소만   2   38  126.589167   35.565833   패류  2011   4   1  -  ...
# ...    ...  ..  ...         ...         ...  ...   ...  ..  .. ..  ...
# 15116  서귀포   1    4   33.216667  126.490000   연안  2013  10  29  -  ...
# 15117  서귀포   1    4   33.216667  126.490000   연안  2013   8   8  -  ...
# 15118  서귀포   1    4   33.216667  126.490000   연안  2013   6  12  -  ...
# 15119  서귀포   1    4   33.216667  126.490000   연안  2013   4   4  -  ...
# 15120  서귀포   1    4   33.216667  126.490000   연안  2013   2  21  -  ...
#
#        NO3-N(표)  NO2-N(표)  DIN(표)  TN(표)  DIP(표)  TP(표)  SIO2-SI(표)  CHL-A(표)  \
# 0         0.160     0.011   0.235  0.532   0.021  0.026       0.451      0.35
# 1         0.020     0.002   0.048  0.120   0.012  0.016       0.144      1.89
# 2         0.080     0.020   0.184  0.752   0.014  0.052       0.301      0.73
# 3         0.020     0.006   0.064  0.433   0.005  0.057       0.193      0.47
# 4         0.010     0.001   0.021  0.116   0.001  0.026       0.036      0.60
# ...         ...       ...     ...    ...     ...    ...         ...       ...
# 15116     0.025     0.002   0.032  0.042   0.002  0.008       0.115      1.14
# 15117     0.001     0.001   0.014  0.040   0.000  0.004       0.218      0.69
# 15118     0.022     0.001   0.052  0.144   0.004  0.008       0.214      0.65
# 15119     0.031     0.007   0.060  0.197   0.005  0.020       0.192      1.55
# 15120     0.051     0.002   0.064  0.274   0.009  0.015       0.199      0.87
#
#        SS(표)   투명도
# 0      192.6   0.7
# 1       79.0   1.3
# 2      116.2   0.3
# 3       32.0   0.7
# 4       14.2   1.0
# ...      ...   ...
# 15116    2.2  12.4
# 15117    1.6  13.8
# 15118    1.2  10.9
# 15119    1.6  10.2
# 15120    1.2  12.2
#
# [14894 rows x 28 columns]

# %%
df1가막만 = df1[df1['어장명']=='가막만'] #표층 3이하 가막만 데이터
df1가막만
# Out:
# Empty DataFrame
# Columns: [어장명, 정점, 정점2, 위도, 경도, 어장종류, 년도, 월, 일, 기상, 수심(m), 수온(표), 수온(차이), 염분(표), Ph(표), DO(표), COD(표), NH4-N(표), NO3-N(표), NO2-N(표), DIN(표), TN(표), DIP(표), TP(표), SIO2-SI(표), CHL-A(표), SS(표), 투명도]
# Index: []
#
# [0 rows x 28 columns]

# %%
df1_가막만 = df1_[df1_['어장명']=='가막만'] #표층 3이상 가막만 데이터
df1_가막만
# Out:
#        어장명  정점  정점2         위도          경도 어장종류    년도  월   일 기상  ...  \
# 10589  가막만   8   38  34.759722  127.552500   어류  2009  9  16  -  ...
# 10590  가막만   8   38  34.759722  127.552500   어류  2009  8   6  -  ...
# 10591  가막만   8   38  34.759722  127.552500   어류  2009  7   2  -  ...
# 10592  가막만   8   38  34.759722  127.552500   어류  2009  5  14  -  ...
# 10719  가막만   9   37  34.744722  127.413889   어류  2009  9   9  -  ...
# ...    ...  ..  ...        ...         ...  ...   ... ..  .. ..  ...
# 13798  가막만   4    1  34.232222  126.553611   패류  2009  9   8  -  ...
# 13799  가막만   4    1  34.232222  126.553611   패류  2009  8   5  -  ...
# 13800  가막만   4    1  34.232222  126.553611   패류  2009  7   8  -  ...
# 13801  가막만   4    1  34.232222  126.553611   패류  2009  5  12  -  ...
# 13802  가막만   4    1  34.232222  126.553611   패류  2009  2  19  -  ...
#
#        NO3-N(표)  NO2-N(표)  DIN(표)  TN(표)  DIP(표)  TP(표)  SIO2-SI(표)  CHL-A(표)  \
# 10589     0.070     0.007   0.101  0.740   0.016  0.036       0.414      1.25
# 10590     0.026     0.001   0.037  0.577   0.002  0.023       0.407      2.57
# 10591     0.019     0.024   0.057  0.758   0.002  0.017       0.486      1.68
# 10592     0.025     0.101   0.132  1.107   0.016  0.028       0.312      2.76
# 10719     0.030     0.002   0.044  0.701   0.003  0.026       0.220      2.05
# ...         ...       ...     ...    ...     ...    ...         ...       ...
# 13798     0.034     0.003   0.054  0.795   0.019  0.045       0.246      2.18
# 13799     0.051     0.003   0.077  0.849   0.009  0.034       0.566      3.79
# 13800     0.012     0.073   0.092  0.720   0.011  0.033       0.172      6.54
# 13801     0.019     0.026   0.047  0.532   0.008  0.029       0.285      2.26
# 13802     0.038     0.047   0.087  0.490   0.012  0.023       0.132      1.72
#
#        SS(표)  투명도
# 10589   16.4  1.1
# 10590   13.2  2.0
# 10591   97.2  2.5
# 10592   12.0  3.4
# 10719   97.2  1.8
# ...      ...  ...
# 13798   18.4  1.0
# 13799  106.4  2.0
# 13800   29.6  2.8
# 13801  129.0  3.3
# 13802   30.8  2.3
#
# [682 rows x 28 columns]

# %%
df1_가막만 = df1_가막만[(df1_가막만['정점'] == 10) & (df1_가막만['어장명'] == '가막만')]
df1_가막만
# Out:
#        어장명  정점  정점2         위도          경도 어장종류    년도   월   일    기상  ...  \
# 11678  가막만  10   18  34.661389  127.652500   패류  2012  12  12     -  ...
# 11679  가막만  10   18  34.661389  127.652500   패류  2012  10  17     -  ...
# 11680  가막만  10   18  34.661389  127.652500   패류  2012   8   3     -  ...
# 11681  가막만  10   18  34.661389  127.652500   패류  2012   6  14     -  ...
# %%
# 산점도 시각화
plt.figure(figsize=(10, 6))
plt.scatter(df1가막만['SIO2-SI(표)'], df1가막만['DO(표)'], color='blue', label='빈산소수괴 발생')
plt.scatter(df1_가막만['SIO2-SI(표)'], df1_가막만['DO(표)'], color='orange', label='정상 데이터')
plt.xlabel('SIO2-SI(표)')
plt.ylabel('DO(표)')
plt.title('빈산소수괴 VS 정상 데이터 산점도')
plt.legend()
plt.grid(True)
plt.show()

# %%
# 산점도 시각화
plt.figure(figsize=(10, 6))
plt.scatter(df1가막만['TN(표)'], df1가막만['DO(표)'], color='blue', label='빈산소수괴 발생')
plt.scatter(df1_가막만['TN(표)'], df1_가막만['DO(표)'], color='orange', label='정상 데이터')
plt.xlabel('TN(표)')
plt.ylabel('DO(표)')
plt.title('빈산소수괴 VS 정상 데이터 산점도')
plt.legend()
plt.grid(True)
plt.show()

# %%
# 산점도 시각화
plt.figure(figsize=(10, 6))
plt.scatter(df1가막만['SIO2-SI(표)'], df1가막만['DO(표)'], color='blue', label='빈산소수괴 발생')
plt.scatter(df1_가막만['SIO2-SI(표)'], df1_가막만['DO(표)'], color='orange', label='정상 데이터')
plt.xlabel('SIO2-SI(표)')
plt.ylabel('DO(표)')
plt.title('빈산소수괴 VS 정상 데이터 산점도')
plt.legend()
plt.grid(True)

# %%
# 산점도 시각화
plt.figure(figsize=(10, 6))
plt.scatter(df1가막만['수온(차이)'], df1가막만['DO(표)'], color='blue', label='빈산소수괴 발생')
plt.scatter(df1_가막만['수온(차이)'], df1_가막만['DO(표)'], color='orange', label='정상 데이터')
plt.xlabel('수온 차이')
plt.ylabel('DO(표)')
plt.title('빈산소수괴 VS 정상 데이터 산점도')
plt.legend()
plt.grid(True)
plt.show()

# %%
df완도 = df1[df1['어장명']=='완도'] #표층 3이하 가막만 데이터
df완도
# Out:
#       어장명  정점  정점2         위도          경도 어장종류    년도  월   일 기상  ...  NO3-N(표)  \
# 12255  완도   1    2  34.584167  127.719722  해조류  2009  5  12  -  ...     0.020
# 12384  완도   3    3  34.573611  127.687222  해조류  2009  5  13  -  ...     0.034
# 12437  완도   2    1  34.572500  127.729444  해조류  2009  5  13  -  ...     0.027
#
#        NO2-N(표)  DIN(표)  TN(표)  DIP(표)  TP(표)  SIO2-SI(표)  CHL-A(표)  SS(표)  \
# 12255     0.019   0.040  0.892   0.004  0.024       0.289      1.75  137.0
# 12384     0.019   0.053  0.963   0.012  0.028       0.255      1.90   24.0
# 12437     0.018   0.047  1.007   0.006  0.026       0.211      2.50  102.0
#
#        투명도
# 12255  1.2
# 12384  1.5
# 12437  1.3
#
# [3 rows x 28 columns]

# %%
df1완도 = df1[df1['어장명']=='완도'] #표층 3이하 가막만 데이터
df1완도
# Out:
#       어장명  정점  정점2         위도          경도 어장종류    년도  월   일 기상  ...  NO3-N(표)  \
# 12255  완도   1    2  34.584167  127.719722  해조류  2009  5  12  -  ...     0.020
# 12384  완도   3    3  34.573611  127.687222  해조류  2009  5  13  -  ...     0.034
# 12437  완도   2    1  34.572500  127.729444  해조류  2009  5  13  -  ...     0.027
#
#        NO2-N(표)  DIN(표)  TN(표)  DIP(표)  TP(표)  SIO2-SI(표)  CHL-A(표)  SS(표)  \
# 12255     0.019   0.040  0.892   0.004  0.024       0.289      1.75  137.0
# 12384     0.019   0.053  0.963   0.012  0.028       0.255      1.90   24.0
# 12437     0.018   0.047  1.007   0.006  0.026       0.211      2.50  102.0
#
#        투명도
# 12255  1.2
# 12384  1.5
# 12437  1.3
#
# [3 rows x 28 columns]

# %%
df1완도 = df1완도[(df1완도['정점'] == 1) & (df1완도['어장명'] == '완도')]
df1완도
# Out:
#       어장명  정점  정점2         위도          경도 어장종류    년도  월   일 기상  ...  NO3-N(표)  \
# 12255  완도   1    2  34.584167  127.719722  해조류  2009  5  12  -  ...      0.02
#
#        NO2-N(표)  DIN(표)  TN(표)  DIP(표)  TP(표)  SIO2-SI(표)  CHL-A(표)  SS(표)  \
# 12255     0.019    0.04  0.892   0.004  0.024       0.289      1.75  137.0
#
#        투명도
# 12255  1.2
#
# [1 rows x 28 columns]

# %%
df1_완도 = df1_[(df1_['정점'] == 1) & (df1_['어장명'] == '완도')]
df1_완도
df1_완도.head()
# Out:
#       어장명  정점  정점2         위도          경도 어장종류    년도  월   일  기상  ...  \
# 12252  완도   1    2  34.584167  127.719722  해조류  2009  9   8   -  ...
# 12253  완도   1    2  34.584167  127.719722  해조류  2009  8   5   -  ...
# 12254  완도   1    2  34.584167  127.719722  해조류  2009  7   8   -  ...
# 12256  완도   1    2  34.584167  127.719722  해조류  2009  2  18   -  ...
# 13081  완도   1    5  34.417500  127.079167   어류  2022  2   8  맑음  ...
#
#        NO3-N(표)  NO2-N(표)  DIN(표)  TN(표)  DIP(표)  TP(표)  SIO2-SI(표)  CHL-A(표)  \
# 12252     0.029     0.004   0.088  0.586   0.004  0.030       0.214      2.35
# 12253     0.054     0.007   0.074  0.767   0.003  0.029       0.386      5.08
# 12254     0.026     0.029   0.056  0.673   0.005  0.017       0.201      4.18
# 12256     0.024     0.119   0.146  0.551   0.017  0.024       0.349      0.80
# 13081     0.002     0.076   0.082  0.211   0.014  0.030       0.331      0.65
#
#        SS(표)  투명도
# 12252   19.2  1.1
# 12253   16.8  2.0
# 12254   40.4  1.5
# 12256   32.8  0.7
# 13081   25.6  1.0
#
# [5 rows x 28 columns]

# %%
# 산점도 시각화
plt.figure(figsize=(10, 6))
plt.scatter(df1완도['SIO2-SI(표)'], df1완도['DO(표)'], color='blue', label='빈산소수괴 발생')
plt.scatter(df1_완도['SIO2-SI(표)'], df1_완도['DO(표)'], color='orange', label='정상 데이터')
plt.xlabel('SIO2-SI(표)')
plt.ylabel('DO(표)')
plt.title('빈산소수괴 VS 정상 데이터 산점도')
plt.legend()
plt.grid(True)
plt.show()

# %%
# 산점도 시각화
plt.figure(figsize=(10, 6))
plt.scatter(df1완도['TN(표)'], df1완도['DO(표)'], color='blue', label='빈산소수괴 발생')
plt.scatter(df1_완도['TN(표)'], df1_완도['DO(표)'], color='orange', label='정상 데이터')
plt.xlabel('TN(표)')
plt.ylabel('DO(표)')
plt.title('빈산소수괴 VS 정상 데이터 산점도')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# 결론 :: 표층에는 어떤 독립변수가 빈산소수괴에 영향을 미치는지 알 수 없다.

# %%
for i in range(df1.shape[0]):
  print(df1.iloc[i]['위도'], df1.iloc[i]['경도'] )
# Out:
# 36.9311111111111 126.344722222222
# 36.9144444444444 126.365277777778
# 34.5841666666667 127.719722222222
# 34.5736111111111 127.687222222222
# 34.5725 127.729444444444

# %%
# import folium
# m = folium.Map(
#     location=[35.0211,128.6810],
#     zoom_start=10
# )

# tooltip = 'Click'

# # for문, f-string이용
# for i in range(df1.shape[0]):
#     folium.Marker(
#         [df1.iloc[i]['위도'], df1.iloc[i]['경도']],
#         popup = f'<strong>{df1.iloc[i]["어장명"]}</br>{df1.iloc[i]["정점2"]}</strong>',
#         tooltip = tooltip
#     ).add_to(m)
# m

# %%
# import pandas as pd

# # 행별로 0인 값의 개수를 세어 새로운 컬럼을 만듭니다.
# df_표['zero_count'] = (df_표 == 0).sum(axis=1)

# # 0인 값의 개수가 2개 이상인 행들을 선택합니다.
# rows_to_delete = df_표[df_표['zero_count'] >= 2]

# # 선택된 행들을 삭제합니다.
# df_표 = df_표.drop(rows_to_delete.index)

# # 'zero_count' 컬럼을 삭제합니다.
# df_표= df_표.drop('zero_count', axis=1)

# # 결과 데이터프레임을 확인합니다.
# print(df_저)

# %%
# import folium
# m = folium.Map(
#     location=[35.0211,128.6810],
#     zoom_start=10
# )

# tooltip = 'Click'

# # for문, f-string이용
# for i in range(df_표.shape[0]):
#     folium.Marker(
#         [df_표.iloc[i]['위도'], df_표.iloc[i]['경도']],
#         popup = f'<strong>{df_표.iloc[i]["어장명"]}</br>{df_표.iloc[i]["정점"]}</strong>',
#         tooltip = tooltip
#     ).add_to(m)
# m

# %%
df가로림만 = df_표[df_표['어장명']=='가로림만'] 
df가로림만
# Out:
#        어장명  정점  정점2         위도          경도 어장종류    년도   월   일  기상  ...  \
# 1786  가로림만   1   15  36.993056  126.311111    김  2021  12  11  맑음  ...
# 1787  가로림만   1   15  36.993056  126.311111    김  2021  10  13  맑음  ...
# 1788  가로림만   1   15  36.993056  126.311111    김  2021   8   2  흐림  ...
O2-N(표)  DIN(표)  TN(표)  DIP(표)  TP(표)  SIO2-SI(표)  CHL-A(표)  SS(표)  \
# 12184     0.004   0.052  0.659   0.008  0.033       0.239      2.01   24.4
# 12185     0.008   0.077  1.029   0.010  0.025       0.395      8.46   15.6
# 12186     0.033   0.060  0.779   0.001  0.016       0.210      4.17   21.6
# 12187     0.029   0.043  0.805   0.013  0.024       0.305      1.24   20.0
# 12188     0.101   0.124  0.537   0.003  0.027       0.342      1.15   54.0
# ...         ...     ...    ...     ...    ...         ...       ...    ...
# 14490     0.011   0.122  0.825   0.013  0.031       0.307      0.91   41.6
# 14491     0.003   0.078  0.649   0.012  0.026       0.318      1.34   16.4
# 14492     0.079   0.100  0.544   0.007  0.026       0.339      1.45   23.2
# 14493     0.037   0.052  0.775   0.005  0.021       0.110      3.95  146.0
# 14494     0.119   0.155  0.824   0.014  0.025       0.237      0.40   14.0
#
#        투명도
# 12184  0.9
# 12185  3.3
# 12186  2.0
# 12187  2.0
# 12188  0.7
# ...    ...
# 14490  1.9
# 14491  1.9
# 14492  0.8
# 14493  2.5
# 14494  1.6
#
# [792 rows x 28 columns]

# %%
df가로림만무 = df가로림만[df가로림만['DO(표)']>3] #표층 DO가 3초과 데이터 4개
df가로림만무
# Out:
#        어장명  정점  정점2         위도          경도 어장종류    년도   월   일  기상  ...  \
# 1786  가로림만   1   15  36.993056  126.311111    김  2021  12  11  맑음  ...
# 1787  가로림만   1   15  36.993056  126.311111    김  2021  10  13  맑음  ...
# 1788  가로림만   1   15  36.993056  126.311111    김  2021   8   2  흐림  ...
# 1789  가로림만   1   15  36.993056  126.311111    김  2021   6   9  맑음  ...
# 1790  가로림만   1   15  36.993056  126.311111    김  2021   4   1  맑음  ...
# ...    ...  ..  ...        ...         ...  ...   ...  ..  ..  ..  ...
# 2112  가로림만   4    1  36.855000  126.310000  바지락  2019   6  12  맑음  ...
# 2113  가로림만   4    1  36.855000  126.310000  바지락  2019   4   8  맑음  ...
# 2114  가로림만   4    1  36.855000  126.310000  바지락  2019   2  14  맑음  ...
# 2115  가로림만   4    1  36.855000  126.310000  바지락  2016   4   7  맑음  ...
# 2116  가로림만   4    1  36.855000  126.310000  바지락  2016   2  21  맑음  ...
#
#       NO3-N(표)  NO2-N(표)  DIN(표)  TN(표)  DIP(표)  TP(표)  SIO2-SI(표)  CHL-A(표)  \
# 1786     0.146     0.002   0.153  0.180   0.028  0.036       0.415      0.95
# 1787     0.057     0.042   0.106  0.150   0.021  0.025       0.237      1.16
# 1788     0.007     0.001   0.023  0.073   0.005  0.023       0.044      1.45
# 1789     0.122     0.009   0.152  0.165   0.021  0.021       0.079      3.43
# 1790     0.119     0.001   0.129  0.212   0.016  0.028       0.198      1.85
# ...        ...       ...     ...    ...     ...    ...         ...       ...
# 2112     0.061     0.004   0.086  0.134   0.011  0.032       0.086      2.87
# 2113     0.069     0.002   0.077  0.255   0.013  0.030       0.229      2.51
# 2114     0.139     0.002   0.150  0.325   0.020  0.038       0.312      2.38
# 2115     0.011     0.002   0.021  0.235   0.007  0.037       0.107      3.32
# 2116     0.136     0.003   0.160  0.323   0.020  0.035       0.450      0.81
#
#       SS(표)  투명도
# 1786   22.6  0.5
# 1787    9.6  3.1
# 1788    8.4  4.1
# 1789   18.6  0.9
# 1790   28.4  1.0
# ...     ...  ...
# 2112   10.0  2.2
# 2113   10.4  1.2
# 2114    8.8  2.0
# 2115   23.8  1.0
# 2116   32.8  0.9
#
# [132 rows x 28 columns]

# %%
df가로림만유 = df가로림만[df가로림만['DO(표)']<=3] #표층 DO가 3초과 데이터 4개
df가로림만유
# Out:
#        어장명  정점  정점2         위도          경도 어장종류    년도   월  일 기상  ...  \
# 1994  가로림만   6    8  36.931111  126.344722   패류  2010  12  1  -  ...
# 2000  가로림만   4    7  36.914444  126.365278   패류  2010  12  1  -  ...
#
#       NO3-N(표)  NO2-N(표)  DIN(표)  TN(표)  DIP(표)  TP(표)  SIO2-SI(표)  CHL-A(표)  \
# 1994     0.121     0.004   0.134  0.512   0.023  0.029       0.306      0.15
# 2000     0.127     0.005   0.139  0.409   0.023  0.025       0.289      0.18
#
#       SS(표)  투명도
# 1994   35.0  0.8
# 2000   31.6  0.7
#
# [2 rows x 28 columns]

# %%
df가로림만 = df가로림만[(df가로림만['정점2'] == 8)]

# %%
df완도 = df완도[(df완도['정점2'] == 3)]

# %%
df가로림만
# Out:
#        어장명  정점  정점2         위도          경도 어장종류    년도   월  일 기상  ...  \
# 1994  가로림만   6    8  36.931111  126.344722   패류  2010  12  1  -  ...
# 1995  가로림만   6    8  36.931111  126.344722   패류  2010  10  6  -  ...
# 1996  가로림만   6    8  36.931111  126.344722   패류  2010   8  8  -  ...
# 1997  가로림만   6    8  36.931111  126.344722   패류  2010   6  8  -  ...
# 1998  가로림만   6    8  36.931111  126.344722   패류  2010   4  3  -  ...
# 1999  가로림만   6    8  36.931111  126.344722   패류  2010   2  4  -  ...
#
#       NO3-N(표)  NO2-N(표)  DIN(표)  TN(표)  DIP(표)  TP(표)  SIO2-SI(표)  CHL-A(표)  \
# 1994     0.121     0.004   0.134  0.512   0.023  0.029       0.306      0.15
# 1995     0.036     0.028   0.071  0.102   0.013  0.018       0.150      0.19
# 1996     0.026     0.005   0.043  0.457   0.009  0.020       0.150      1.62
# 1997     0.112     0.004   0.123  0.290   0.012  0.031       0.271      0.72
# 1998     0.093     0.002   0.103  0.230   0.015  0.031       0.294      0.99
# 1999     0.142     0.002   0.149  0.237   0.022  0.047       0.491      1.64
#
#       SS(표)  투명도
# 1994   35.0  0.8
# 1995   29.2  1.4
# 1996    8.6  1.2
# 1997   23.6  0.8
# 1998   29.4  0.9
# 1999   10.8  0.5
#
# [6 rows x 28 columns]

# %%
df가로림만 = df가로림만[['수온(표)','수온(차이)','염분(표)','Ph(표)',
           'COD(표)', 'NH4-N(표)', 'NO3-N(표)', 'NO2-N(표)','DO(표)',
           'DIN(표)', 'TN(표)', 'DIP(표)', 'TP(표)','SIO2-SI(표)','CHL-A(표)','SS(표)','투명도']]

# %%
df완도 = df완도[['수온(표)','수온(차이)','염분(표)','Ph(표)',
           'COD(표)', 'NH4-N(표)', 'NO3-N(표)', 'NO2-N(표)','DO(표)',
           'DIN(표)', 'TN(표)', 'DIP(표)', 'TP(표)','SIO2-SI(표)','CHL-A(표)','SS(표)','투명도']]

# %%
가로림만_corr = df가로림만.corr()

# %%
완도_corr = df완도.corr()

# %%
tips_corr_heatmap = sns.heatmap(가로림만_corr,
                                cbar=True,
                                annot=True,
                                cmap='GnBu',
                                vmin=-1.0,
                                vmax=1.0)
plt.figure(figsize=(12, 9))
plt.show()

# %%
tips_corr_heatmap = sns.heatmap(완도_corr,
                                cbar=True,
                                annot=True,
                                cmap='GnBu',
                                vmin=-1.0,
                                vmax=1.0)
plt.figure(figsize=(12, 9))
plt.show()
